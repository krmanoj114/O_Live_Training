# %% [markdown]
# # Exploratory Data Analysis with Python

# %% [markdown]
# This is the notebook for the O'Reilly Live Training - Exploratory Data Analysis with Python by Pratheerth Padman

# %% [markdown]
# ## Introduction to EDA

# %% [markdown]
# The dataset we're going to be using throughout the session, can be found at - https://www.kaggle.com/fedesoriano/stroke-prediction-dataset

# %% [markdown]
# #### Importing the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
sns.set(style="whitegrid", font_scale=1.5)
# %matplotlib inline
plt.rcParams['figure.figsize'] = [12, 8]

# %% [markdown]
# #### First look at the dataset!

# %% [markdown]
# Here, we'll be using pandas to read the downloaded csv file. We'll then print the number of rows and columns in the dataset using the shape function.
#
# Then we'll get our first look at the dataset using the head function which by default prints out the first 5 rows of the dataset. If we want to print out the last 5 rows, we can use the tail function. We can also specify the number of rows we want to be printed out in the head or tail functions.

# %%
# importing the dataset

data_df = pd.read_csv("../data/healthcare-dataset-stroke-data.csv")

# %%
# shape of the dataset

print("The dataset has {} rows and {} columns".format(data_df.shape[0], data_df.shape[1]))
# Out:
# The dataset has 5110 rows and 12 columns

# %%
# first few rows of the dataset

data_df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# last few rows

data_df.tail(3)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5107       0
# 5108       0
# 5109       0

# %%
pd.set_option('display.max_rows', 10)

#pd.set_option('display.max_rows' None)

# %%
data_df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
# transpose

data_df.head().T
# Out:
#                                  0             1             2       3  \
# id                            9046         51676         31112   60182
# gender                        Male        Female          Male  Female
# age                             67            61            80      49
# hypertension                     0             0             0       0
# heart_disease                    1             0             1       0
# ...                            ...           ...           ...     ...
# Residence_type               Urban         Rural         Rural   Urban
# avg_glucose_level           228.69        202.21        105.92  171.23
# bmi                           36.6           NaN          32.5    34.4
# smoking_status     formerly smoked  never smoked  never smoked  smokes
# stroke                           1             1             1       1
#
#                               4
# id                         1665
# gender                   Female
# age                          79
# hypertension                  1
# heart_disease                 0
# ...                         ...
# Residence_type            Rural
# avg_glucose_level        174.12
# bmi                          24
# smoking_status     never smoked
# stroke                        1
#
# [12 rows x 5 columns]

# %% [markdown]
# #### Attribute Information

# %% [markdown]
# > 1) **id:** unique identifier
#
# > 2) **gender:** "Male", "Female" or "Other"
#
# > 3) **age:** age of the patient
#
# > 4) **hypertension:** 0 if the patient doesn't have hypertension, 1 if the patient has hypertension
#
# > 5) **heart_disease:** 0 if the patient doesn't have any heart diseases, 1 if the patient has a heart disease
#
# > 6) **ever_married:** "No" or "Yes"
#
# > 7) **work_type:** "children", "Govt_jov", "Never_worked", "Private" or "Self-employed"
#
# > 8) **Residence_type:** "Rural" or "Urban"
#
# > 9) **avg_glucose_level:** average glucose level in blood
#
# > 10) **bmi:** body mass index
#
# > 11) **smoking_status:** "formerly smoked", "never smoked", "smokes" or "Unknown"*
#
# > 12) **stroke:** 1 if the patient had a stroke or 0 if not
#
# *Note: "Unknown" in smoking_status means that the information is unavailable for this patient

# %% [markdown]
# #### The Info Function

# %% [markdown]
# The info function helps us to identify the number of columns, if there are any missing values and also the type of features/variables that are in the dataset.
# Here "object" means its a categorical feature and both "int64" and "float64" means it is numerical.

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %% [markdown]
# #### Filter the dataset using datatype

# %%
data_df.select_dtypes(include=["object"])
# Out:
#       gender ever_married      work_type Residence_type   smoking_status
# 0       Male          Yes        Private          Urban  formerly smoked
# 1     Female          Yes  Self-employed          Rural     never smoked
# 2       Male          Yes        Private          Rural     never smoked
# 3     Female          Yes        Private          Urban           smokes
# 4     Female          Yes  Self-employed          Rural     never smoked
# ...      ...          ...            ...            ...              ...
# 5105  Female          Yes        Private          Urban     never smoked
# 5106  Female          Yes  Self-employed          Urban     never smoked
# 5107  Female          Yes  Self-employed          Rural     never smoked
# 5108    Male          Yes        Private          Rural  formerly smoked
# 5109  Female          Yes       Govt_job          Urban          Unknown
#
# [5110 rows x 5 columns]

# %%
data_df.select_dtypes(include=["number"])
# Out:
#          id   age  hypertension  heart_disease  avg_glucose_level   bmi  \
# 0      9046  67.0             0              1             228.69  36.6
# 1     51676  61.0             0              0             202.21   NaN
# 2     31112  80.0             0              1             105.92  32.5
# 3     60182  49.0             0              0             171.23  34.4
# 4      1665  79.0             1              0             174.12  24.0
# ...     ...   ...           ...            ...                ...   ...
# 5105  18234  80.0             1              0              83.75   NaN
# 5106  44873  81.0             0              0             125.20  40.0
# 5107  19723  35.0             0              0              82.99  30.6
# 5108  37544  51.0             0              0             166.29  25.6
# 5109  44679  44.0             0              0              85.28  26.2
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 7 columns]

# %% [markdown]
# #### Which person has the max bmi from the dataset?

# %%
data_df["bmi"]
# Out:
# 0       36.6
# 1        NaN
# 2       32.5
# 3       34.4
# 4       24.0
#         ...
# 5105     NaN
# 5106    40.0
# 5107    30.6
# 5108    25.6
# 5109    26.2
# Name: bmi, Length: 5110, dtype: float64

# %%
data_df["bmi"].max()
# Out:
# 97.6

# %%
data_df[data_df.bmi == data_df.bmi.max()]
# Out:
#          id gender   age  hypertension  heart_disease ever_married work_type  \
# 2128  56420   Male  17.0             1              0           No   Private
#
#      Residence_type  avg_glucose_level   bmi smoking_status  stroke
# 2128          Rural              61.67  97.6        Unknown       0

# %%
max_bmi_person = data_df[data_df.bmi == data_df.bmi.max()]

# %%
max_bmi_person.id
# Out:
# 2128    56420
# Name: id, dtype: int64

# %% [markdown]
# #### Questions on initial glance

# %% [markdown]
# > 1. Is gender correlated with stroke? Are males or females more likely to get it?
# > 2. How much does having hypertension and heart disease affect occurence of a stroke?
# > 3. What is the age distribution in the dataset? Are older people more likely to get it?
# > 4. Is the assumption that if you've ever smoked, you're much more likely to get a stroke true?

# %% [markdown]
# ## Excercise - 01

# %% [markdown]
# 1. What is the value of the 10th observation of the age feature from the top of the dataset?

# %%
data_df["age"][9]
# Out:
# 78.0

# %% [markdown]
# 2. What is the value of the 7th observation of the bmi feature from the bottom of the dataset?

# %%
data_df.bmi[len(data_df) - 7]
# Out:
# 46.9

# %% [markdown]
# 3. What is the id number and work_type of the person with the lowest average_glucose_level in the dataset

# %%
id_num = data_df[data_df["avg_glucose_level"] == data_df["avg_glucose_level"].min()].id

work_type_person = data_df[data_df["avg_glucose_level"] == data_df["avg_glucose_level"].min()].work_type

print(id_num)
print(work_type_person)
# Out:
# 4886    60562
# Name: id, dtype: int64
# 4886    Private
# Name: work_type, dtype: object

# %% [markdown]
# 4. Print out a filtered dataframe, based on three conditions:
#
#    a) Age is less than 30
#    b) Residence_type is Rural
#    c) Gender is female
#
#    How many rows are there in the filtered dataset?

# %%
cond1 = data_df["age"] < 30
cond2 = data_df["Residence_type"] == "Rural"
cond3 = data_df["gender"] == "Female"

data_df[cond1 & cond2 & cond3]
# Out:
#          id  gender    age  hypertension  heart_disease ever_married  \
# 245   49669  Female  14.00             0              0           No
# 292   44338  Female  16.00             0              0           No
# 294   34974  Female  22.00             0              0           No
# 312   68249  Female  27.00             0              0          Yes
# 328   29865  Female  21.00             0              0           No
# ...     ...     ...    ...           ...            ...          ...
# 5027  62416  Female  26.00             0              0          Yes
# 5031  67465  Female  20.00             0              0           No
# 5032  67426  Female   1.24             0              0           No
# 5089  56714  Female   0.72             0              0           No
# 5104  14180  Female  13.00             0              0           No
#
#      work_type Residence_type  avg_glucose_level   bmi smoking_status  stroke
# 245   children          Rural              57.93  30.9        Unknown       1
# 292   children          Rural             110.63  19.5        Unknown       0
# 294    Private          Rural              79.81  27.7        Unknown       0
# 312    Private          Rural              85.60  21.4        Unknown       0
# 328    Private          Rural              89.44  21.9         smokes       0
# ...        ...            ...                ...   ...            ...     ...
# 5027   Private          Rural              73.29  27.8   never smoked       0
# 5031   Private          Rural             117.59  17.1   never smoked       0
# 5032  children          Rural              61.94  20.3        Unknown       0
# 5089  children          Rural              62.13  16.8        Unknown       0
# 5104  children          Rural             103.08  18.6        Unknown       0
#
# [430 rows x 12 columns]

# %% [markdown]
# ## Univariate Data Analysis

# %% [markdown]
# #### Data Description

# %% [markdown]
# The data describe function helps to print out some basic summary statistics like count, mean, standard deviation, max value, min value and the 25th, 50th and 75th percentile of each of the variables. It works for both numerical and categorical features, but in different ways.

# %%
# data description for numerical columns

data_df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
# rounding off the numbers

round(data_df.describe(), 2)
# Out:
#              id      age  hypertension  heart_disease  avg_glucose_level  \
# count   5110.00  5110.00        5110.0        5110.00            5110.00
# mean   36517.83    43.23           0.1           0.05             106.15
# std    21161.72    22.61           0.3           0.23              45.28
# min       67.00     0.08           0.0           0.00              55.12
# 25%    17741.25    25.00           0.0           0.00              77.24
# 50%    36932.00    45.00           0.0           0.00              91.88
# 75%    54682.00    61.00           0.0           0.00             114.09
# max    72940.00    82.00           1.0           1.00             271.74
#
#            bmi   stroke
# count  4909.00  5110.00
# mean     28.89     0.05
# std       7.85     0.22
# min      10.30     0.00
# 25%      23.50     0.00
# 50%      28.10     0.00
# 75%      33.10     0.00
# max      97.60     1.00

# %% [markdown]
# #### Target Variable - Stroke

# %%
# occurences of each value

data_df.stroke.value_counts()
# Out:
# 0    4861
# 1     249
# Name: stroke, dtype: int64

# %%
# stroke - pie chart

stroke_labels = ["No Stroke", "Stroke"]

sizes = data_df.stroke.value_counts()

plt.pie(x=sizes, labels=stroke_labels, autopct="%1.1f%%")

plt.title("Stroke - Pie Chart")

plt.show()

# %% [markdown]
# A large percentage - 95.1 % of the dataset contains people who've not had a heart attack / stroke. This means the dataset is highly imbalanced. In this situation, the predictive model developed using conventional machine learning algorithms could be biased and inaccurate.
#
# This happens because Machine Learning Algorithms are usually designed to improve accuracy by reducing the error. Thus, they do not take into account the class distribution / proportion or balance of classes.
#
# Before applying machine learning models to this dataset, this particular problem will need to be kept in mind.

# %% [markdown]
# #### Continuous Numerical Features - age, avg_glucose_level, bmi

# %% [markdown]
# **Histogram**
#
# A histogram displays numerical data by grouping data into "bins" of equal width. Each bin is plotted as a bar whose height corresponds to how many data points are in that bin.

# %%
# single plot - age

sns.set_style("whitegrid", {'axes.grid' : False})

sns.histplot(data_df.age, bins=30).set(title="Histogram of Age", xlabel="Age in Years")

plt.show()

# %% [markdown]
# There is a fairly even distribution of age with little dips and peaks. The highest peak comes in the late 50’s and the lowest dip comes after 70 I’d say. There doesn’t seem to be any outliers.

# %%
# age histogram in people with stroke

sns.histplot(data_df.age[data_df["stroke"]==1], bins=30).set(title="Histogram of Age with Stroke", xlabel="Age in Years")

plt.show()

# %% [markdown]
# We can see a definite lean towards the older side for people who've had stroke

# %%
# subplots - bmi, avg_glucose_level

fig, (ax1, ax2) = plt.subplots(nrows=1,ncols=2, figsize=(15,10))

sns.histplot(data_df.bmi, bins=30, ax=ax1).set(title="Histogram of BMI", xlabel="BMI")
sns.histplot(data_df.avg_glucose_level, bins=30, ax=ax2, color="green").set(title="Histogram of Glucose Level", xlabel="Glucose Level (mg/dl)")

for ax in fig.axes:
    plt.sca(ax)
    plt.tick_params(labelsize=15)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Boxplots and Outliers

# %% [markdown]
# A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”). It can tell you about your outliers and what their values are. It can also tell you if your data is symmetrical, how tightly your data is grouped, and if and how your data is skewed.

# %% [markdown]
# ![title](../assets/boxplot1.png)
#
# Image Credit: https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51

# %%
# boxplot - age, bmi, avg_glucose_leve

fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(15,8))

sns.boxplot(data_df.age, ax=ax1, palette="Greens").set(title="Boxplot - Age")
sns.boxplot(data_df.bmi, ax=ax2, palette="Blues").set(title="Boxplot - BMI")
sns.boxplot(data_df.avg_glucose_level, ax=ax3, palette="Set1").set(title="Boxplot - Glucose Level")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Should We Remove or Keep Outliers?

# %% [markdown]
# Since we're trying to predict or analyse a situation wherein a person has/will have a stroke, some of the records are bound to have outlier values for a few features. In such cases, outliers might help us in predicting the occurence of a stroke, so in this case we won't be removing outliers.

# %% [markdown]
# #### Categorical Features - gender, ever_married, work_type, residence_type, smoking_status

# %%
# data description for non-numerical columns

data_df.describe(exclude = ["number"])
# Out:
#         gender ever_married work_type Residence_type smoking_status
# count     5110         5110      5110           5110           5110
# unique       3            2         5              2              4
# top     Female          Yes   Private          Urban   never smoked
# freq      2994         3353      2925           2596           1892

# %% [markdown]
# #### Countplot

# %%
# countplots for gender, ever_married and work_type

fig, ax = plt.subplots(1, 3, figsize=(15,8))

sns.countplot(data_df.gender, ax=ax[0]).set(title="Gender")
sns.countplot(data_df.ever_married, ax=ax[1]).set(title="Have they ever married?")
sns.countplot(data_df.work_type, ax=ax[2]).set(title="What type of work do they do?")

plt.tight_layout()

for ax in fig.axes:
    plt.sca(ax)
    plt.xticks(rotation=45)

plt.show()

# %%
# same thing as above for people who've had a stroke

fig, ax = plt.subplots(1, 3, figsize=(15,8))

sns.countplot(data_df.gender[data_df["stroke"]==1], ax=ax[0]).set(title="Gender")
sns.countplot(data_df.ever_married[data_df["stroke"]==1], ax=ax[1]).set(title="Have they ever married?")
sns.countplot(data_df.work_type[data_df["stroke"]==1], ax=ax[2]).set(title="What type of work do they do?")

plt.tight_layout()

for ax in fig.axes:
    plt.sca(ax)
    plt.xticks(rotation=45)

plt.show()

# %%
# countplots for residence_type and smoking_status

fig, ax = plt.subplots(1, 2, figsize=(15,8))

sns.countplot(data_df.Residence_type, ax=ax[0]).set(title="Where do they live?")
sns.countplot(data_df.smoking_status, ax=ax[1]).set(title="Have they smoked?")

plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
# same as above for people who've had a stroke

fig, ax = plt.subplots(1, 2, figsize=(15,8))

sns.countplot(data_df.Residence_type[data_df["stroke"]==1], ax=ax[0]).set(title="Where do they live?")
sns.countplot(data_df.smoking_status[data_df["stroke"]==1], ax=ax[1]).set(title="Have they smoked?")

plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bivariate Data Analysis

# %% [markdown]
# #### Do older people tend to get more strokes?

# %%
sns.boxplot(data_df.stroke, data_df.age)
plt.show()

# %% [markdown]
# #### Is there a connection between the type of work you do and your bmi?

# %%
sns.violinplot(data_df.work_type, data_df.bmi)
plt.show()

# %% [markdown]
# #### Do older people have a higher average glucose level?

# %%
sns.scatterplot(data_df.age, data_df.avg_glucose_level, hue=data_df.stroke)
plt.show()

# %%
# linear regression model - shows trend
sns.regplot(data_df.age, data_df.avg_glucose_level)
plt.show()

# %% [markdown]
# #### Smoking vs Stroke and Work Type vs Hypertension

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,8))

sns.countplot(x="stroke", hue="smoking_status", data=data_df, ax=ax[0]).set(title="Smoking vs Stroke")
sns.countplot(x="hypertension", hue="work_type", data=data_df, ax=ax[1], palette="Set2").set(title="Work Type vs Hypertension")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exercise

# %% [markdown]
#    Create a 3 plot figure to answer the following questions:
#
#    a) What is the percentage of people with hypertension in the dataset?
#
#    b) In the different values of the feature "smoking_status", do men outnumber the women in any of them?
#
#    c) What can you tell me about the relationship between the type of work and age of a person in the dataset?
#
#    All figures should contain titles.

# %%
# pie plot

ht_labels = ["No HT", "HT"]

sizes_ht = data_df.hypertension.value_counts()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(15,15))

ax1.pie(x=sizes_ht, labels=ht_labels, autopct="%1.1f%%")
ax1.set_title("Pie Chart - HyperTension")

sns.countplot(x="gender", hue="smoking_status", data=data_df, ax=ax2).set(title= "Men vs Women - Smoking Status")

sns.violinplot(data_df.work_type, data_df.age, ax=ax3).set(title = "Worktype vs Age")

plt.tight_layout()
plt.show()

# %%
min_age_se = data_df[data_df.work_type=="Self-employed"].age.min()
min_age_se
# Out:
# 7.0

# %%
data_df[(data_df.age == min_age_se)  & (data_df.work_type == "Self-employed")]
# Out:
#         id gender  age  hypertension  heart_disease ever_married  \
# 410  54975   Male  7.0             0              0           No
#
#          work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# 410  Self-employed          Rural              64.06  18.9        Unknown
#
#      stroke
# 410       0

# %% [markdown]
# ## Missing Data

# %%
# percentage of missing data

(data_df.isnull().sum()/len(data_df))*100
# Out:
# id                   0.000000
# gender               0.000000
# age                  0.000000
# hypertension         0.000000
# heart_disease        0.000000
#                        ...
# Residence_type       0.000000
# avg_glucose_level    0.000000
# bmi                  3.933464
# smoking_status       0.000000
# stroke               0.000000
# Length: 12, dtype: float64

# %%
data_df.bmi.mean()
# Out:
# 28.893236911794673

# %%
data_df.bmi.median()
# Out:
# 28.1

# %%
data_df[data_df["bmi"].isnull()]
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 1     51676  Female  61.0             0              0          Yes
# 8     27419  Female  59.0             0              0          Yes
# 13     8213    Male  78.0             0              1          Yes
# 19    25226    Male  57.0             0              1           No
# 27    61843    Male  58.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5039  42007    Male  41.0             0              0           No
# 5048  28788    Male  40.0             0              0          Yes
# 5093  32235  Female  45.0             1              0          Yes
# 5099   7293    Male  40.0             0              0          Yes
# 5105  18234  Female  80.0             1              0          Yes
#
#           work_type Residence_type  avg_glucose_level  bmi   smoking_status  \
# 1     Self-employed          Rural             202.21  NaN     never smoked
# 8           Private          Rural              76.15  NaN          Unknown
# 13          Private          Urban             219.84  NaN          Unknown
# 19         Govt_job          Urban             217.08  NaN          Unknown
# 27          Private          Rural             189.84  NaN          Unknown
# ...             ...            ...                ...  ...              ...
# 5039        Private          Rural              70.15  NaN  formerly smoked
# 5048        Private          Urban             191.15  NaN           smokes
# 5093       Govt_job          Rural              95.02  NaN           smokes
# 5099        Private          Rural              83.94  NaN           smokes
# 5105        Private          Urban              83.75  NaN     never smoked
#
#       stroke
# 1          1
# 8          1
# 13         1
# 19         1
# 27         1
# ...      ...
# 5039       0
# 5048       0
# 5093       0
# 5099       0
# 5105       0
#
# [201 rows x 12 columns]

# %%
# create a missing indicator feature for bmi

data_df["bmi_nan"] = np.where(data_df["bmi"].isnull(), 1, 0)

# %%
data_df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke  bmi_nan
# 0       1        0
# 1       1        1
# 2       1        0
# 3       1        0
# 4       1        0

# %%
# fill missing bmi values with mean

data_df["bmi"].fillna(data_df["bmi"].mean(), inplace=True)

data_df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level        bmi  \
# 0        Private          Urban             228.69  36.600000
# 1  Self-employed          Rural             202.21  28.893237
# 2        Private          Rural             105.92  32.500000
# 3        Private          Urban             171.23  34.400000
# 4  Self-employed          Rural             174.12  24.000000
#
#     smoking_status  stroke  bmi_nan
# 0  formerly smoked       1        0
# 1     never smoked       1        1
# 2     never smoked       1        0
# 3           smokes       1        0
# 4     never smoked       1        0

# %% [markdown]
# ## Correlation Analysis

# %%
# pearson correlation

data_df.corr()
# Out:
#                          id       age  hypertension  heart_disease  \
# id                 1.000000  0.003538      0.003550      -0.001296
# age                0.003538  1.000000      0.276398       0.263796
# hypertension       0.003550  0.276398      1.000000       0.108306
# heart_disease     -0.001296  0.263796      0.108306       1.000000
# avg_glucose_level  0.001092  0.238171      0.174474       0.161857
# bmi                0.002999  0.325942      0.160189       0.038899
# stroke             0.006388  0.245257      0.127904       0.134914
# bmi_nan           -0.127634  0.078956      0.093046       0.098621
#
#                    avg_glucose_level           bmi    stroke       bmi_nan
# id                          0.001092  2.998925e-03  0.006388 -1.276343e-01
# age                         0.238171  3.259425e-01  0.245257  7.895620e-02
# hypertension                0.174474  1.601888e-01  0.127904  9.304595e-02
# heart_disease               0.161857  3.889871e-02  0.134914  9.862057e-02
# avg_glucose_level           1.000000  1.687514e-01  0.131945  9.195693e-02
# bmi                         0.168751  1.000000e+00  0.038947  2.978629e-16
# stroke                      0.131945  3.894660e-02  1.000000  1.412383e-01
# bmi_nan                     0.091957  2.978629e-16  0.141238  1.000000e+00

# %%
# spearman correlation

data_df.corr(method="spearman")
# Out:
#                          id       age  hypertension  heart_disease  \
# id                 1.000000  0.003741      0.003553      -0.001205
# age                0.003741  1.000000      0.280647       0.269627
# hypertension       0.003553  0.280647      1.000000       0.108306
# heart_disease     -0.001205  0.269627      0.108306       1.000000
# avg_glucose_level -0.053058  0.145168      0.114041       0.106360
# bmi                0.004275  0.363661      0.162437       0.065341
# stroke             0.006499  0.249531      0.127904       0.134914
# bmi_nan           -0.127835  0.079953      0.093046       0.098621
#
#                    avg_glucose_level       bmi    stroke   bmi_nan
# id                         -0.053058  0.004275  0.006499 -0.127835
# age                         0.145168  0.363661  0.249531  0.079953
# hypertension                0.114041  0.162437  0.127904  0.093046
# heart_disease               0.106360  0.065341  0.134914  0.098621
# avg_glucose_level           1.000000  0.113696  0.082541  0.058334
# bmi                         0.113696  1.000000  0.055015  0.033266
# stroke                      0.082541  0.055015  1.000000  0.141238
# bmi_nan                     0.058334  0.033266  0.141238  1.000000

# %%
# correlation heatmap

sns.heatmap(data_df.corr(), annot=True)
#plt.savefig("heatmap.jpeg")
plt.show()
